# %%
# !pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /home/nicole/.local/lib/python3.10/site-packages (16.1.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow) (1.24.4)
# DEPRECATION: python-debian 0.1.43ubuntu1 has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of python-debian or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import pickle
import os
import pandas as pd
import pyarrow
import pyarrow.parquet as pa

# %%
# # Read EBNeRD dataset

# # BEHAVIORS
# train_behaviors_path = "../DATA/ebnerd/train/behaviors.parquet"
# val_behaviors_path = "../DATA/ebnerd/validation/behaviors.parquet"

# train_behaviors = pa.read_table(train_behaviors_path) 
# val_behaviors = pa.read_table(val_behaviors_path)

# # HISTORY
# train_history_path = "../DATA/ebnerd/train/history.parquet"
# val_history_path = "../DATA/ebnerd/validation/history.parquet"

# train_history = pa.read_table(train_history_path) 
# val_history = pa.read_table(val_history_path)

# # ARTICLES
# articles_path = "../DATA/ebnerd/articles.parquet"

# articles = pa.read_table(articles_path)

# %%
# Read in user history, i.e. dictionary containing all histories per user {<user_id>: {<article_id>, ...}}
user_history_path = "../DATA/user_history_selection/histories_pickle.txt"
user_history = pickle.load(open(user_history_path, 'rb'))

# %%
print(pd. __version__)
# Out:
# 1.4.4

# %%
K = 5
res = dict(list(user_history.items())[0: K])
print(res)
# Out:
# {'2444624': {'9746033', '9747437', '9752566', '9762125', '9740711', '9742764', '9769917', '9748798', '9747518', '9761047', '9751349', '9768467', '9765153', '9768328', '9754288', '9751524', '9753503', '9744625', '9757308', '9740106', '9764617', '9743207', '9760290', '9767868', '9768707', '9764070', '9754133', '9730301', '9760998', '9742280', '9756441', '9761620', '9769891', '9746488', '9744263', '9756745', '9750815', '9765641', '9738447', '9748447', '9746558', '9768583', '9745154', '9747328', '9698128', '9769580', '9746627', '9750687', '9755224', '9756295', '9762439', '9762694', '9760675', '9764378', '9744347', '9756546', '9754388', '9764564', '9750872', '9751593', '9735495', '9754603', '9758025', '9740003', '9749034', '9764765', '9744356', '9752332', '9736693', '9757607', '9770638', '9767071', '9748948', '9748043', '9739179', '9756987', '9746170', '9765582', '9768260', '9759708', '9740843', '9756602', '9740400', '9756020', '9744733', '9761842', '9757479', '9749240', '9760437', '9757533', '9753047', '9763880', '9755999', '9750696', '9755734', '9741997', '9761359', '9744070', '9761635', '9750161', '9767604', '9762352', '9765169', '9741106', '9760809', '9741415', '9762718', '9742619', '9748519', '9549298', '9763668', '5944936', '9752731', '9764461', '9757857', '9763952', '9758252', '9714946', '9745130', '9748080', '9766599', '