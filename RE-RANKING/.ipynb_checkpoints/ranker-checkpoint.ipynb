# %%
import pandas as pd


data_path = "../DATA/weights/tf_idf_english.txt"
# data_path = open(data_path, 'rb')

# DATA/weights/tf_idf_english.txt
# RE-RANKING/ranker.ipynb

# read text file into pandas DataFrame
df = pd.read_csv(data_path, sep=" ", header=None)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 8
#       4 data_path = "../DATA/weights/tf_idf_english.txt"
#       5 # data_path = open(data_path, 'rb')
#       6
#       7 # read text file into pandas DataFrame
# ----> 8 df = pd.read_csv(data_path, sep=" ", header=None)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# display DataFrame
print(df)
