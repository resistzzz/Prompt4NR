# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /home/nicole/Code/MSc_AI/Recommender_Systems/Prompt4NR/.venv/lib/python3.10/site-packages (16.1.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/nicole/Code/MSc_AI/Recommender_Systems/Prompt4NR/.venv/lib/python3.10/site-packages (from pyarrow) (1.24.4)

# %%
import pickle
import os
import pandas as pd
import pyarrow
import pyarrow.parquet as pa

# %%
# # Read EBNeRD dataset

# # BEHAVIORS
# train_behaviors_path = "../DATA/ebnerd/train/behaviors.parquet"
# val_behaviors_path = "../DATA/ebnerd/validation/behaviors.parquet"

# train_behaviors = pa.read_table(train_behaviors_path) 
# val_behaviors = pa.read_table(val_behaviors_path)

# # HISTORY
# train_history_path = "../DATA/ebnerd/train/history.parquet"
# val_history_path = "../DATA/ebnerd/validation/history.parquet"

# train_history = pa.read_table(train_history_path) 
# val_history = pa.read_table(val_history_path)

# # ARTICLES
# articles_path = "../DATA/ebnerd/articles.parquet"

# articles = pa.read_table(articles_path)

# %%
# Read in user history, i.e. dictionary containing all histories per user {<user_id>: {<article_id>, ...}}
user_history_path = "../DATA/weights/histories_pickle.txt"
user_history = pickle.load(open(user_history_path, 'rb'))

# %%
K = 5
res = dict(list(user_history.items())[0: K])
print(res)
# Out:
# {'2444624': {'9750189', '9757372', '9755580', '9751139', '9754288', '9756317', '9767368', '9756028', '9759951', '9757857', '9742936', '9767868', '9745016', '9738832', '9753295', '9759708', '9759142', '9768707', '9761620', '9759051', '9753503', '9768193', '9751564', '9748129', '9767528', '9749034', '9755025', '9767948', '9767071', '9753080', '9745929', '9558040', '9762377', '9749284', '9750078', '9752890', '9769917', '9753168', '9759927', '9767557', '9740332', '9750726', '9747411', '9758326', '9756190', '9766136', '9744601', '9750304', '9748035', '9754000', '7530879', '9742509', '9766944', '9764642', '9750873', '5944936', '9754136', '9762836', '9755027', '9753479', '9744880', '9754413', '9746068', '9741802', '9740427', '9765153', '9736646', '9750500', '9747328', '9735866', '9745524', '9754536', '9747859', '9770452', '9767534', '9761699', '9764461', '9755102', '9748706', '9743229', '9759109', '9761862', '9764651', '9765539', '9740952', '9746694', '9203696', '9754025', '9729988', '9752566', '9750696', '9741176', '9762288', '9742145', '9768882', '9758057', '9760112', '9768260', '9748186', '9520286', '9750358', '9741309', '9770328', '4681209', '9768860', '9762125', '9748678', '9742627', '9767602', '9758538', '9739179', '9750002', '9685790', '9748213', '9735495', '9770333', '9765582', '9747404',